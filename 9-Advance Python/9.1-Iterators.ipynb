# %% [markdown]
# ## Iterators
# Iterators are advanced Python concepts that allow for efficient looping and memory managament. Iterators provide a way to access elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]

for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
## Iterator 
iterator = iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
## Iterate throgh all the element,
next(iterator)
# Out:
# 2

# %%
try:
    print(next(iterator))
except StopIteration:
    print("there are no element in the iterator ")
# Out:
# there are no element in the iterator
