# %%
#variable
a=100

# %%
##Declaring and assiging variables 
age=27
height=5.4
name="manisha karki"
is_student=True

##Printing the variable
print("age :",age)
print("Height: ",height)
print("name: ",name)
print(is_student)
# Out:
# age : 27
# Height:  5.4
# name:  manisha karki
# True

# %% [markdown]
# #Naming conventions
# #Variable name should be descriptive
# #They must start with a letter or an '_' and contain letter , number and underscores
# #Variable names case sensitive

# %%
##Invalid variable names
#1age=30
# first-name

# @name=

# %%
first_name="Naran"
last_name="khadka"
print(first_name)
print(last_name)
# Out:
# Naran
# khadka

# %%
##Case sensitivity
name="naran"
Name="naran"
name==Name
# Out:
# True

# %%
##Understanding Variable types
##pyton is dynamically typed, type of variable is determined at runtime. 

age=24 # int 
height=5.3 #float
name="naran"
print(type(name))
# Out:
# <class 'str'>

# %%
# Type checking and conversion 
type(height)
# Out:
# float

# %%
age=12
print(type(age))

## type conversion 

age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 12
# <class 'str'>

# %%
age='12'
print(type(age))
age_int=int(age)
print(age_int)
print(type(age_int))
# Out:
# <class 'str'>
# 12
# <class 'int'>

# %%
name="naran"
print(type(name))
name_int=int(name)
print(type(name_int))
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 name="naran"
#       2 print(type(name))
# ----> 3 name_int=int(name)
#       4 print(type(name_int))
#
# ValueError: invalid literal for int() with base 10: 'naran'

# %%
##Dyanmic typing 
##Python allows the type of variable to change as the program executes 


var=10 #int 
print(var," ",type(var))

var="hello"
print(var," ",type(var))

var=243.4
print(var," ",type(var))
# Out:
# 10   <class 'int'>
# hello   <class 'str'>
# 243.4   <class 'float'>

# %%
## input in type 
## user want to gives some values 

age= int(input("What is the age"))
print(age,type(age))
# Out:
# 23 <class 'int'>

# %% [markdown]
# A simple calculator

# %%
#A simple calculate in python 

num1=float(input("Enter your first number"))
num2=float(input("Enter your first number"))
sum=num1+num2
diff=num1-num2
mult=num1*num2
division=num1/num2
print("sum:",sum)
print("difference :",diff)
print("multiple:",mult)
print("divison:",division)
# Out:
# sum: 25.0
# difference : 15.0
# multiple: 100.0
# divison: 4.0
