# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# code to print hello world
print ("Hello , World!")
# Out:
# Hello , World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Python pram to takes a user input and print it 

name=input("Please enter your full name Sir !")
print(name)
# Out:
# Naran khadka

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
#program to check if a numebr is positive or negetive or zero 

number=int(input("Please enter number to check positive ,negetive or zero"))
if(number>0):
    print("The ",number,"is Positive")
elif(number<0):
        print("The ",number,"is negetive")
else:
        print("The ",number,"is zero")
# Out:
# The  -50 is negetive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# A program to find the largest of three numbers 
num1=float(input("enter your first number"))
num2=float(input("enter your second number"))
num3=float(input("enter your third number"))

if(num1>=num2) and (num1>=num3):
    print("the largest number is ",num1," Number 1") 
elif(num2>=num3):
    print("the largest number is ",num2," Number 2") 
else:
    print("the largest number is ",num3 ," Number 3")
# Out:
# the largest number is  30.0  Number 1

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# a program to calculate the factorial of a  number
# factorial is the n*n-1
num=int(input("Please enter the number")) 
if num< 0:
    print("Factorial is not defined for negative numbers")
elif(num==0):
     print("The factorial of", num, "is 1")

else: 
    result = 1
    for i in range(1,num+1):  # range(1, num+1) is used because Python's range() does not include the last number (num) so the factorial need upto num , we add the num+1 
        result=result*i
    print("The factorial of", num, "is", result)
# Out:
# The factorial of 5 is 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
#  a program to create different data types and print their values and types 
age= 23 # int 
height= 5.3 # float 
name="naran"
is_true=True # boolean 

print(age, type(age))
print(height, type(height))
print(name, type(name))
print(is_true, type(is_true))
# Out:
# 23 <class 'int'>
# 5.3 <class 'float'>
# naran <class 'str'>
# True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# A python program to swap the values of two variable 

num1 = 30 
num2 = 40 
print("Before swapping the values or variable ")
print("the num1 is ", num1)
print("the num2 is ", num2)
temp=num1
num1=num2
num2=temp
print("after swapping the value")
print("the num1 is ", num1)
print("the num2 is ", num2)
# Out:
# Before swapping the values or variable
# the num1 is  30
# the num2 is  40
# after swapping the value
# the num1 is  40
# the num2 is  30

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# A python program to convert Celsius to Fahrenheit. 
celsius = float(input("Enter the Celsius for convert into Fahrenheit."))
if celsius==0:
    print("the ",celsius," celsius is equal to 32 fahrenheit ")
else:
    fahrenheit=float((celsius*9)/5 +32)# becase Temperature in degrees Fahrenheit (°F) = (Temperature in degrees Celsius (°C) * 9/5) + 32.
    print("The ",celsius, " celsius is equal to ",fahrenheit ,"fahrenheit")
# Out:
# The  5.0  celsius is equal to  41.0 fahrenheit

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# A python program to concatenate two strings 
str1="naran"
str2="khadka"
concatenate_str=str1+" "+str2
print(concatenate_str)
# Out:
# naran khadka

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# A Python program to check if a variable is of a specific data type 
age = 23 
if isinstance(age, int):  # isinstance() is a built-in Python function used to check whether a value (object) belongs to a specific data type (class).
    print(f"{age} is int")
else:
    print(f"{age} is float")
# Out:
# 23 is int

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# A python program to perform arithemetic operations operations: addition, subtraction, multiplication, and division.

num1 = float(input("Enter first number"))
num2 = float(input("Enter Second number"))

add=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2

print(f"addition: {add}")
print(f"subtraction: {sub}")
print(f"multiplication: {mul}")
print(f"division: {div}")
# Out:
# addition: 30.0
# subtraction: 10.0
# multiplication: 200.0
# division: 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
#  A python program to demostrate comparison operator , equal to , not equal to , greater than , less than 

num1=10
num2=30

if num1==num2:
    print(" This is same number")
if num1!=num2:
    print("this is not same number")
if num1>num2:
    print(f"{num1} is greater than {num2}")
if num1<num2:
     print(f"{num2} is greater than {num1}")
# Out:
# this is not same number
# 30 is greater than 10

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# A python program to demostrate logical operators : and , or , not
a = 5
b = 3

print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
# Out:
# 5 == 3: False
# 5 != 3: True
# 5 > 3: True
# 5 < 3: False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
#  A python program to calculate the square of a given numer 

number=int(input("Enter a number to calculate the square "))
print(f"The square of {number } is {number*number}")
# Out:
# The square of 2 is 4

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# A Python program to check if a number is even or odd. 
number=int(input("Enter a number"))
if number%2==0:
    print(f"The given number {number} is even")
else:
    print(f"The given number {number} is odd")
# Out:
# The given number 23023 is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# A python program to find the sum of the first n natural numbers 
number = int(input("Enter a natural number "))
sum=0
for i in range(1,number+1):
    sum+=i
print(f"The sum of the first n natural number {number } is {sum}")
# Out:
# The sum of the first n natural number 5 is 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
#  A python program to check if a year is a leap year or not 
'''if (year % 400 == 0) then leap_year
else if (year % 100 == 0) then not_leap_year
else if (year % 4 == 0) then leap_year
else not_leap_year
'''

year=int(input ("Enter a year to check wheather enter year is leap year or not"))

if year%400==0:
    print(f"The enter year { year} is leap year")
elif year%4==0:
    print(f"The enter year { year} is leap year")
elif year%100==0:
    print(f"The enter year { year} is not leap year")
else:
     print(f"The enter year { year} is not leap year")
# Out:
# The enter year 2024 is leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# A python program to reverse a string 

'''str1="naran khadka"
rev=str1[::-1]
print(rev)'''

# using the for loop
s="hello"
rev=""
for ch in s:
    rev=ch+rev
print(rev)

# In Python, a + b means "a comes first, then b"
# So order matters:
# rev + ch → adds character at the end
# ch + rev → adds character at the beginning (used for reversing)
# Out:
# olleh

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# A python program to check if a s string is a palindrome or not 

str1=input("Enter a string to check palindrome or not ")
# first reverse it 
rev=""
for i in str1:
    rev=i+rev
print("the revese string is "+ rev)

if(str1==rev):
    print("the given string is palindrome ")
else:
    print("The given string is not palindrome")
# Out:
# the revese string is olleh
# The given string is not palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# A python program to sort a list of numbers in ascending order . 

arr =[64, 34, 25, 12, 22, 11, 90]
n = len(arr)
for i in range(n):  ## default starting point is 0 and will run upto n-1
    swapped=False
    for j in range (0,n-i-1):
        if arr[j] >arr[j+1]:
            arr[j],arr[j+1]=arr[j+1],arr[j]
            swapped=True
        if not swapped:
            break
print(arr)

'''Explanation:

for i in range(n): Runs multiple passes; each pass positions the next largest element at the end.
swapped = False: Flag to detect if any swap occurs in the current pass.
for j in range(0, n - i - 1): Iterates through unsorted elements; range shrinks as the end becomes sorted.
if arr[j] > arr[j + 1]: Checks for inversion between adjacent elements.
arr[j], arr[j + 1] = arr[j + 1], arr[j]: Swaps elements in place using tuple unpacking.
if not swapped: break, Stops early if no swaps occur, indicating the array is already sorted.'''
# Out:
# [12, 22, 11, 25, 34, 64, 90]
# 'Explanation:\n\nfor i in range(n): Runs multiple passes; each pass positions the next largest element at the end.\nswapped = False: Flag to detect if any swap occurs in the current pass.\nfor j in range(0, n - i - 1): Iterates through unsorted elements; range shrinks as the end becomes sorted.\nif arr[j] > arr[j + 1]: Checks for inversion between adjacent elements.\narr[j], arr[j + 1] = arr[j + 1], arr[j]: Swaps elements in place using tuple unpacking.\nif not swapped: break, Stops early if no swaps occur, indicating the array is already sorted.'
