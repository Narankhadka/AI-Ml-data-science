# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name':['Naran','Ram','Peter','Linda'],
    'Age' : [21,30,35,43],
    'City': ['Kathmandu','Bhaktapur','Berlin','London'],
    'Salary' : [100000,40000,42000,80000]
}
df =pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age       City  Salary
# 0  Naran   21  Kathmandu  100000
# 1    Ram   30  Bhaktapur   40000
# 2  Peter   35     Berlin   42000
# 3  Linda   43     London   80000

# %%
data_list = [
    ['john',28,'New York',65000],
    ['Anna',34,'Paris',70000],
    ['Peter',29,'Berlin',62000],
    ['linda',42,'London',85000]    
]

df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary" ]
df2=pd.DataFrame(data_list,columns=columns)
print(df2)
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  linda   42    London   85000

# %% [markdown]
# ## Selecting and Indexing of Columns

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   john  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  linda    London

# %% [markdown]
# ## Adding a new column

# %%
df2['Designation'] = ['Manager','Coder','Doctor','Developer']
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   john   28  New York   65000     Manager
# 1   Anna   34     Paris   70000       Coder
# 2  Peter   29    Berlin   62000      Doctor
# 3  linda   42    London   85000   Developer

# %% [markdown]
# ## Removing columns

# %%
df2.drop(['City','Salary'],axis = 1 )
# Out:
#     Name  Age
# 0   john   28
# 1   Anna   34
# 2  Peter   29
# 3  linda   42

# %%
df2.drop(0,axis = 0 )
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  linda   42  London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  linda   42    London   85000

# %% [markdown]
# ## Selecting Rows

# %%
df2.loc[[0,1]] # loc = location it is keyword
# Out:
#    Name  Age      City  Salary
# 0  john   28  New York   65000
# 1  Anna   34     Paris   70000

# %%
df2.iloc[3]
# Out:
# Name       linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  linda   42    London   85000

# %%
#Selecting subsets of rows and columns 

df2.loc[[0 , 1]] [["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df2.loc[[2,3]] [["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  linda   42

# %% [markdown]
# ### Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  linda   42    London   85000

# %% [markdown]
# ### I only want to see those people whose age is above 30

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  linda   42  London   85000

# %% [markdown]
# ### I only want people whose age is above 30 and their city must be paris

# %%
df2[(df2["Age"]> 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
