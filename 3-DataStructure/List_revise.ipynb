# %%
lst=[]

# %%
## accessing the list elements using index

fruits = ['apple', 'banana', 'cherry']
print(fruits[0])
# Out:
# apple

# %%
## modigying the list elements

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[1]
# Out:
# 'banana'

# %%
fruits[1] = "watermelon"

# %%
fruits
# Out:
# ['apple', 'watermelon', 'cherry']

# %%
fruits[1:]="watermelon"

# %%
fruits
# Out:
# ['apple', 'w', 'a', 't', 'e', 'r', 'm', 'e', 'l', 'o', 'n']

# %%
#lits methods

# %%
fruits.append('orange') ## add an item to the end of the list

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
## i want to add the item at the specific index

# %%
fruits.insert(1,"watermelon") ## add an item at the specific index

# %%
fruits
# Out:
# ['apple', 'watermelon', 'banana', 'cherry', 'orange']

# %%
fruits.remove("banana") ## remove the item from the list

# %%
fruits
# Out:
# ['apple', 'watermelon', 'cherry', 'orange']

# %%
popped_fruits=fruits.pop() ## remove the last item from the list

# %%
popped_fruits
# Out:
# 'orange'

# %%
index= fruits.index("cherry") ## return the index of the item
print(index)
# Out:
# 2
