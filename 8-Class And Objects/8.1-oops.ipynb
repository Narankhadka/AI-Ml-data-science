# %% [markdown]
# ## Classes and Objects

# %% [markdown]
# Object-Oriente programming(OOP) is a programming paradiagm that uses "objects" to design applications and computer programs. OOPs allows for modeling real-world scenarios using classes and objects. I am learning the basics of creating clasess and objects. including instance variable and method in python.

# %%
### A class is a blue print for creating objects. it has Attributes and methods

class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
print (audi)
# Out:
# <class '__main__.Car'>
# ...

# %%
audi.windows=4
print(audi.windows)
dir(audi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 audi.windows=4
#       2 print(audi.windows)
#       3 dir(audi)
#
# NameError: name 'audi' is not defined

# %%
class Dog: 
    ## constructor 
    def __init__(self,name,age):
        self.name=name
        self.age=age

## creae objects

dog1=Dog(name='buddy',age=2)
print(dog1.name)
print(dog1.age)
# Out:
# buddy
# 2

# %%
## Define a class with instance Methods
class Dog:
    def __init__(self, name,age):
        self.name=name
        self.age=age
    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("buddy",3)
dog1.bark()
dog2=Dog("Lucy",5)
dog2.bark()
# Out:
# buddy says woof
# Lucy says woof

# %%
### Modelling a Bank Account 

## Define a class for bank account 

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposite(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited, New balance is {self.balance}")
    def withdraw(self,amount):
        if amount>self.balance:
            print(" Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn. New balace is {self.balance}")
    def get_balance(self):
            return self.balance

## Create an account 
account=BankAccount("Naran",5000)
print(account.balance)
# Out:
# 5000

# %%
## Call instance method 
account.deposite(100)
# Out:
# 100 is deposited, New balance is 5100

# %%
## withdraw money 
account.withdraw(122323)
# Out:
#  Insufficient funds!

# %%
account.withdraw(1000)
# Out:
# 1000 is withdrawn. New balace is 4000

# %%
print(account.get_balance())
# Out:
# 4000

# %% [markdown]
# ### Conclusion
# OOP allows we to model real-world scenarios using classes and objects. In this section , i learned how to create classes and objects , define instance variable and methos. and use them to perform various operations. Understanding these concepts is fundamental to writting effective and maintanable python code.
